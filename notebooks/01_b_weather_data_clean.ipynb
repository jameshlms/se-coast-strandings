# %% [markdown]
# # <p style="text-align: center; font-size: 2.5rem">Notebook I</p>
#
# <p style="text-align: center; font-size: 2rem">Part b</p>
